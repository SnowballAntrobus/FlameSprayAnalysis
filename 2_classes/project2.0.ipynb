# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, LeaveOneOut, GridSearchCV
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# # Dataset setup

# %% [markdown]
# ## Load the dataset from .csv file

# %%
input_file = "data.csv"
df = pd.read_csv(input_file, header = 0)
df.describe()
# Out:
#        # Liquid Flow Rate (mL/min)    Atomization O2 Flow Rate (L/min)   \
# count                     53.000000                           53.000000
# mean                       8.866792                            9.269434
# std                        1.633283                            1.564203
# min                        6.060000                            6.180000
# 25%                        7.500000                            8.100000
# 50%                        8.940000                            9.420000
# 75%                       10.000000                           10.500000
# max                       11.900000                           11.900000
#
#         Sheath O2 Flow Rate (L/min)    ER1 (EtOH/AtomO2)   \
# count                      53.000000            53.000000
# mean                        9.767925             0.848491
# std                         3.051593             0.170963
# min                         5.100000             0.510000
# 25%                         6.900000             0.760000
# 50%                         9.900000             0.840000
# 75%                        12.500000             0.960000
# max                        14.900000             1.160000
#
#         ER2 (EtOH/AtomO2+SheathO2)  Burner Cap Temperature     Result
# count                    53.000000               53.000000  53.000000
# mean                      0.416226              166.018868   0.735849
# std                       0.107188               34.320599   0.445099
# min                       0.230000              130.000000   0.000000
# 25%                       0.350000              137.000000   0.000000
# 50%                       0.400000              146.000000   1.000000
# 75%                       0.490000              203.000000   1.000000
# max                       0.660000              219.000000   1.000000

# %% [markdown]
# ## Split into input (X) and output (y) variables

# %%
dataset = df.values
X = dataset[:,1:7]
y = dataset[:,7]
y = y.astype('int')

# %% [markdown]
# # Analyze dataset

# %% [markdown]
# ## Check if data is skewed
# What should my threshold be? I chose to combine Unstable and unstable

# %%
sns.catplot(x="Category", kind="count", data=df)
count = df["Result"].value_counts()
count = count.tolist()
print(f"Stable: {count[0] / len(X) * 100} %")
print(f"Unstable: {count[1] / len(X) * 100} %")
# Out:
# Stable: 73.58490566037736 %
# Unstable: 26.41509433962264 %

# %% [markdown]
# ## Finding patterns graphically

# %% [markdown]
# ### Pair plots and histograms of stable vs unstable

# %%
sns.pairplot(df[df.columns.difference(['Result'])], hue='Category')

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Prepare data for models

# %% [markdown]
# ### Standardize the data for ease of use and increased performance
# Should I be scaling the only the train and will it affect my model?

# %%
scale = StandardScaler().fit(X)
X_std = scale.transform(X)

# %% [markdown]
# ### Split into train and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X_std, y, train_size=.9)

# %% [markdown]
# ### Leave one out cross validation

# %%
loo = LeaveOneOut()
loo.get_n_splits(X_train)
# Out:
# 47

# %% [markdown]
# ## PCA

# %% [markdown]
# ### 2D

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_std)

# %%
stable = np.array([0.0,0.0])
unstable = np.array([0.0,0.0])
for i in range(len(X_pca)):
    if y[i] == 1:
        stable = np.append(stable, X_pca[i])
    elif y[i] == 0:
        unstable = np.append(unstable, X_pca[i])
    else:
        continue
stable = stable.reshape((count[0]+1, 2))
unstable = unstable.reshape((count[1]+1, 2))

# %%
fig, ax = plt.subplots()
ax.scatter(stable[1:, 0], stable[1:, 1], alpha=0.5)
ax.scatter(unstable[1:, 0], unstable[1:, 1], marker="^")
ax.set_title("PCA")
fig.legend(["Stable", "unstable", "Unstable"])

# %% [markdown]
# ### 3D

# %%
# %matplotlib notebook

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# %%
stable = np.array([0.0,0.0,0.0])
unstable = np.array([0.0,0.0,0.0])
for i in range(len(X_pca)):
    if y[i] == 1:
        stable = np.append(stable, X_pca[i])
    elif y[i] == 0:
        unstable = np.append(unstable, X_pca[i])
    else:
        continue
stable = stable.reshape((count[0]+1, 3))
unstable = unstable.reshape((count[1]+1, 3))

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(stable[1:, 0], stable[1:, 1], stable[1:, 2], alpha=0.5)
ax.scatter(unstable[1:, 0], unstable[1:, 1], unstable[1:, 2], marker="^")
ax.set_title("PCA")
# Out:
# <div id='1b779b4a-2496-4a48-b2f7-5915b3b23bd1'></div>
# Text(0.5, 0.92, 'PCA')
# <div id='46f11448-5141-4aed-82f4-99078131cba1'></div>

# %% [markdown]
# ## Linear

# %%
parameters = {'solver': ['newton-cg', 'lbfgs', 'liblinear'],'C': [1, 100, 1000]}
log = LogisticRegression(multi_class='auto', max_iter=1000)
clf = GridSearchCV(log, parameters, cv=loo)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'C': 1000, 'solver': 'newton-cg'}
# 0.8936170212765957

# %% [markdown]
# ## SVC

# %%
parameters = {'kernel': ['rbf', 'linear', 'poly'],'C': [1, 100, 1000]}
svc = SVC(gamma="scale")
clf = GridSearchCV(svc, parameters, cv=loo)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'C': 1000, 'kernel': 'linear'}
# 0.9361702127659575

# %% [markdown]
# ## KNN

# %%
parameters = {'n_neighbors': [2, 3, 4, 5, 6], 'p' : [1, 2]}
knn = KNeighborsClassifier()
clf = GridSearchCV(knn, parameters, cv=loo)
clf.fit(X_train, y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'n_neighbors': 3, 'p': 2}
# 0.9148936170212766

# %% [markdown]
# ## Decision Tree

# %%
score = 0
for train_index, cross_index in loo.split(X_train):
    X_train, X_cross = X[train_index], X[cross_index]
    y_train, y_cross = y[train_index], y[cross_index]
    tree = DecisionTreeClassifier()
    tree.fit(X_train, y_train)
    score += tree.score(X_cross, y_cross)
print(f"Score: {score / 53}")
# Out:
# Score: 0.7169811320754716

# %% [markdown]
# ## Ensemble Methods

# %% [markdown]
# ### Random Forest

# %%
score = 0
for train_index, cross_index in loo.split(X_train):
    X_train, X_cross = X[train_index], X[cross_index]
    y_train, y_cross = y[train_index], y[cross_index]
    forest = RandomForestClassifier(n_estimators=500)
    forest.fit(X_train, y_train)
    score += forest.score(X_cross, y_cross)
print(f"Score: {score / 53}")
# Out:
# Score: 0.660377358490566

# %% [markdown]
# ### Ada Boost

# %%
score = 0
for train_index, cross_index in loo.split(X_train):
    X_train, X_cross = X[train_index], X[cross_index]
    y_train, y_cross = y[train_index], y[cross_index]
    ada = AdaBoostClassifier(n_estimators=100)
    ada.fit(X_train, y_train)
    score += ada.score(X_cross, y_cross)
print(f"Score: {score / 53}")
# Out:
# Score: 0.7358490566037735
